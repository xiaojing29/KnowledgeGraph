# %%
from pyshacl import validate

# %%
shapes_graph = """
@prefix ex: <http://example.com/ns#> .
@prefix sh: <http://www.w3.org/ns/shacl#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix myOnto: <http://www.mysemantics.com/ontology/> .

ex:PersonShape a sh:NodeShape ;
    sh:targetClass myOnto:Person ;
    sh:property[ 
        sh:path myOnto:hasWikipageID ;
        sh:minInclusive 1 ;
        sh:datatype xsd:integer ;     
    ] .
"""

# %%
data_graph = """
@prefix myOnto: <http://www.mysemantics.com/ontology/> .
@prefix dbo: <http://dbpedia.org/ontology/> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix dbr: <http://dbpedia.org/resource/> .

dbr:Amy_Wadge a myOnto:Person ;
    dbo:birthName "Amy Victoria Wadge"@en ;
    myOnto:hasWikipageID 3159640 ;
    rdfs:label "Amy Wadge"@en ;
    rdfs:comment "An English singer and songwriter."@en . 
"""

# %%
# Valid data graph with shapes graph
conforms, v_graph, v_text = validate(data_graph= data_graph,
                                     shacl_graph=shapes_graph,
                                     data_graph_format='turtle',
                                     shacl_graph_format='turtle',
                                     inference="rdfs",
                                     debug=True,
                                     serialize_report_graph=True)
print(conforms)
print(v_graph)
print(v_text)
# Out:
# Cloning DataGraph to temporary memory graph before pre-inferencing.
# Running pre-inferencing with option='rdfs'.
# Found 1 SHACL Shapes defined with type sh:NodeShape.
# Found 0 SHACL Shapes defined with type sh:PropertyShape.
# Found 0 property paths to follow.
# Found 1 implied SHACL Shapes based on their properties.
# Found 1 implied SHACL Shapes used as values in shape-expecting constraints.
# Cached 1 unique NodeShapes and 1 unique PropertyShapes.
# Will run validation on 1 named graph/s.
# Validating DataGraph named N5478bbe8df8f489c8855f11ff82230c3
# Checking if Shape <NodeShape http://example.com/ns#PersonShape> defines its own targets.
# Identifying targets to find focus nodes.
# Milliseconds to find focus nodes: 0.053ms
# Found 1 Focus Nodes to evaluate.
# Running evaluation of Shape <NodeShape http://example.com/ns#PersonShape>
# Current shape evaluation path: <NodeShape http://example.com/ns#PersonShape>
# Checking conformance for constraint: <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>
# Running evaluation of Shape <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>
# Shape was passed 1 Focus Node/s to evaluate.
# Current shape evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>> -> <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>
# Checking conformance for constraint: <MinInclusiveConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>> -> <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1> -> <MinInclusiveConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>
# Milliseconds to check constraint <MinInclusiveConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>: 0.325ms
# DataGraph conforms to constraint <MinInclusiveConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>.
# Checking conformance for constraint: <DatatypeConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>> -> <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1> -> <DatatypeConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>
# Milliseconds to check constraint <DatatypeConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>: 0.226ms
# DataGraph conforms to constraint <DatatypeConstraintComponent on <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>>.
# Milliseconds to evaluate shape <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1>: 2.257ms
# Milliseconds to check constraint <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>: 3.094ms
# DataGraph conforms to constraint <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>.
# Milliseconds to evaluate shape <NodeShape http://example.com/ns#PersonShape>: 3.909ms
# Checking if Shape <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1> defines its own targets.
# Identifying targets to find focus nodes.
# Milliseconds to find focus nodes: 0.023ms
# Found 0 Focus Nodes to evaluate.
# Skipping shape <PropertyShape n6a94c2b57fbe4e4390ec36833fe159afb1> because it found no focus nodes.
# True
# b'@prefix sh: <http://www.w3.org/ns/shacl#> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n[] a sh:ValidationReport ;\n    sh:conforms true .\n\n'
# Validation Report
# Conforms: True

# %%
shapes_graph = """
@prefix ex: <http://example.com/ns#> .
@prefix sh: <http://www.w3.org/ns/shacl#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix myOnto: <http://www.mysemantics.com/ontology/> .

ex:PersonShape a sh:NodeShape ;
    sh:targetClass myOnto:Person ;
    sh:property[ 
        sh:path myOnto:hasWikipageID ;
        sh:maxInclusive 1 ;
        sh:datatype xsd:integer ;     
    ] .
"""

# %%
####### We give two myOnto:hasWikipageID, so this should be false.

data_graph = """
@prefix myOnto: <http://www.mysemantics.com/ontology/> .
@prefix dbo: <http://dbpedia.org/ontology/> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix dbr: <http://dbpedia.org/resource/> .

dbr:Amy_Wadge a myOnto:Person ;
    dbo:birthName "Amy Victoria Wadge"@en ;
    myOnto:hasWikipageID 3159640 ;
    myOnto:hasWikipageID 3159641 ;
    rdfs:label "Amy Wadge"@en ;
    rdfs:comment "An English singer and songwriter."@en . 
"""

# %%
####### We give two myOnto:hasWikipageID, so this should be false.
conforms, v_graph, v_text = validate(data_graph= data_graph,
                                     shacl_graph=shapes_graph,
                                     data_graph_format='turtle',
                                     shacl_graph_format='turtle',
                                     inference="rdfs",
                                     debug=True,
                                     serialize_report_graph=True)
print(conforms)
print(v_graph)
print(v_text)
# Out:
# Cloning DataGraph to temporary memory graph before pre-inferencing.
# Running pre-inferencing with option='rdfs'.
# Found 1 SHACL Shapes defined with type sh:NodeShape.
# Found 0 SHACL Shapes defined with type sh:PropertyShape.
# Found 0 property paths to follow.
# Found 1 implied SHACL Shapes based on their properties.
# Found 1 implied SHACL Shapes used as values in shape-expecting constraints.
# Cached 1 unique NodeShapes and 1 unique PropertyShapes.
# Will run validation on 1 named graph/s.
# Validating DataGraph named N2cf4b9fd26774b22bb72f47ef94f47b4
# Checking if Shape <NodeShape http://example.com/ns#PersonShape> defines its own targets.
# Identifying targets to find focus nodes.
# Milliseconds to find focus nodes: 0.031ms
# Found 1 Focus Nodes to evaluate.
# Running evaluation of Shape <NodeShape http://example.com/ns#PersonShape>
# Current shape evaluation path: <NodeShape http://example.com/ns#PersonShape>
# Checking conformance for constraint: <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>
# Running evaluation of Shape <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>
# Shape was passed 1 Focus Node/s to evaluate.
# Current shape evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>> -> <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>
# Checking conformance for constraint: <MaxInclusiveConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>> -> <PropertyShape ncf3a180ccc594926b60ee739de30997ab1> -> <MaxInclusiveConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>
# Milliseconds to check constraint <MaxInclusiveConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>: 0.725ms
# Focus nodes do _not_ conform to constraint <MaxInclusiveConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>.
# Checking conformance for constraint: <DatatypeConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#PersonShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>> -> <PropertyShape ncf3a180ccc594926b60ee739de30997ab1> -> <DatatypeConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>
# Milliseconds to check constraint <DatatypeConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>: 0.202ms
# DataGraph conforms to constraint <DatatypeConstraintComponent on <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>>.
# Milliseconds to evaluate shape <PropertyShape ncf3a180ccc594926b60ee739de30997ab1>: 2.495ms
# Milliseconds to check constraint <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>: 3.383ms
# Focus nodes do _not_ conform to constraint <PropertyConstraintComponent on <NodeShape http://example.com/ns#PersonShape>>.
# Constraint Violation in MaxInclusiveConstraintComponent (http://www.w3.org/ns/shacl#MaxInclusiveConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:datatype xsd:integer ; sh:maxInclusive Literal("1", datatype=xsd:integer) ; sh:path myOnto:hasWikipageID ]
# 	Focus Node: dbr:Amy_Wadge
# 	Value Node: Literal("3159640", datatype=xsd:integer)
# 	Result Path: myOnto:hasWikipageID
# 	Message: Value is not <= Literal("1", datatype=xsd:integer)
#
# Constraint Violation in MaxInclusiveConstraintComponent (http://www.w3.org/ns/shacl#MaxInclusiveConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:datatype xsd:integer ; sh:maxInclusive Literal("1", datatype=xsd:integer) ; sh:path myOnto:hasWikipageID ]
# 	Focus Node: dbr:Amy_Wadge
# 	Value Node: Literal("3159641", datatype=xsd:integer)
# 	Result Path: myOnto:hasWikipageID
# 	Message: Value is not <= Literal("1", datatype=xsd:integer)
#
# Milliseconds to evaluate shape <NodeShape http://example.com/ns#PersonShape>: 4.716ms
# Checking if Shape <PropertyShape ncf3a180ccc594926b60ee739de30997ab1> defines its own targets.
# Identifying targets to find focus nodes.
# Milliseconds to find focus nodes: 0.019ms
# Found 0 Focus Nodes to evaluate.
# Skipping shape <PropertyShape ncf3a180ccc594926b60ee739de30997ab1> because it found no focus nodes.
# False
# b'@prefix myOnto: <http://www.mysemantics.com/ontology/> .\n@prefix sh: <http://www.w3.org/ns/shacl#> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n[] a sh:ValidationReport ;\n    sh:conforms false ;\n    sh:result [ a sh:ValidationResult ;\n            sh:focusNode <http://dbpedia.org/resource/Amy_Wadge> ;\n            sh:resultMessage "Value is not <= Literal(\\"1\\", datatype=xsd:integer)" ;\n            sh:resultPath myOnto:hasWikipageID ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:MaxInclusiveConstraintComponent ;\n            sh:sourceShape _:ncf3a180ccc594926b60ee739de30997ab1 ;\n            sh:value 3159641 ],\n        [ a sh:ValidationResult ;\n            sh:focusNode <http://dbpedia.org/resource/Amy_Wadge> ;\n            sh:resultMessage "Value is not <= Literal(\\"1\\", datatype=xsd:integer)" ;\n            sh:resultPath myOnto:hasWikipageID ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:MaxInclusiveConstraintComponent ;\n            sh:sourceShape _:ncf3a180ccc594926b60ee739de30997ab1 ;\n            sh:value 3159640 ] .\n\n_:ncf3a180ccc594926b60ee739de30997ab1 sh:datatype xsd:integer ;\n    sh:maxInclusive 1 ;\n    sh:path myOnto:hasWikipageID .\n\n'
# Validation Report
# Conforms: False
# Results (2):
# Constraint Violation in MaxInclusiveConstraintComponent (http://www.w3.org/ns/shacl#MaxInclusiveConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:datatype xsd:integer ; sh:maxInclusive Literal("1", datatype=xsd:integer) ; sh:path myOnto:hasWikipageID ]
# 	Focus Node: dbr:Amy_Wadge
# 	Value Node: Literal("3159640", datatype=xsd:integer)
# 	Result Path: myOnto:hasWikipageID
# 	Message: Value is not <= Literal("1", datatype=xsd:integer)
# Constraint Violation in MaxInclusiveConstraintComponent (http://www.w3.org/ns/shacl#MaxInclusiveConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:datatype xsd:integer ; sh:maxInclusive Literal("1", datatype=xsd:integer) ; sh:path myOnto:hasWikipageID ]
# 	Focus Node: dbr:Amy_Wadge
# 	Value Node: Literal("3159641", datatype=xsd:integer)
# 	Result Path: myOnto:hasWikipageID
# 	Message: Value is not <= Literal("1", datatype=xsd:integer)

# %%
shapes_graph = """
@prefix ex: <http://example.com/ns#> .
@prefix sh: <http://www.w3.org/ns/shacl#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix myOnto: <http://www.mysemantics.com/ontology/> .
@prefix dbo: <http://dbpedia.org/ontology/> .

ex:SongShape a sh:NodeShape ;
    sh:targetClass myOnto:Song ;
    sh:property[ 
        sh:path dbo:releaseDate ;
        sh:datatype xsd:date ;     
    ] .
"""

# %%
data_graph = """
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix myOnto: <http://www.mysemantics.com/ontology/> .
@prefix dbo: <http://dbpedia.org/ontology/> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix dbr: <http://dbpedia.org/resource/> .

dbr:Best_Part_of_Me a myOnto:Song ;
    myOnto:hasName "Best Part of Me"@en ;
    dbo:artist dbr:Ed_Sheeran ;
    dbo:writer dbr:Benny_Blanco,
        dbr:Ed_Sheeran,
        dbr:Yebba ;
    dbo:genre dbr:Pop_music ;
    dbo:producer dbr:Benny_Blanco ;
    dbo:recordLabel dbr:Asylum_Records,
        dbr:Atlantic_Records ;
    dbo:releaseDate "2019-07-05"^^xsd:date ;
    rdfs:label "Best Part of Me"@en ;
    rdfs:comment "A song by English singer-songwriter Ed Sheeran."@en .  
"""

# %%
# Valid data graph with shapes graph
conforms, v_graph, v_text = validate(data_graph= data_graph,
                                     shacl_graph=shapes_graph,
                                     data_graph_format='turtle',
                                     shacl_graph_format='turtle',
                                     inference="rdfs",
                                     debug=True,
                                     serialize_report_graph=True)
print(conforms)
print(v_graph)
print(v_text)
# Out:
# Cloning DataGraph to temporary memory graph before pre-inferencing.
# Running pre-inferencing with option='rdfs'.
# Found 1 SHACL Shapes defined with type sh:NodeShape.
# Found 0 SHACL Shapes defined with type sh:PropertyShape.
# Found 0 property paths to follow.
# Found 1 implied SHACL Shapes based on their properties.
# Found 1 implied SHACL Shapes used as values in shape-expecting constraints.
# Cached 1 unique NodeShapes and 1 unique PropertyShapes.
# Will run validation on 1 named graph/s.
# Validating DataGraph named N4d554de1556e4c448fcf70d32ce65892
# Checking if Shape <NodeShape http://example.com/ns#SongShape> defines its own targets.
# Identifying targets to find focus nodes.
# Milliseconds to find focus nodes: 0.035ms
# Found 1 Focus Nodes to evaluate.
# Running evaluation of Shape <NodeShape http://example.com/ns#SongShape>
# Current shape evaluation path: <NodeShape http://example.com/ns#SongShape>
# Checking conformance for constraint: <PropertyConstraintComponent on <NodeShape http://example.com/ns#SongShape>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#SongShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#SongShape>>
# Running evaluation of Shape <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1>
# Shape was passed 1 Focus Node/s to evaluate.
# Current shape evaluation path: <NodeShape http://example.com/ns#SongShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#SongShape>> -> <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1>
# Checking conformance for constraint: <DatatypeConstraintComponent on <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1>>
# Current constraint evaluation path: <NodeShape http://example.com/ns#SongShape> -> <PropertyConstraintComponent on <NodeShape http://example.com/ns#SongShape>> -> <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1> -> <DatatypeConstraintComponent on <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1>>
# Milliseconds to check constraint <DatatypeConstraintComponent on <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1>>: 0.236ms
# DataGraph conforms to constraint <DatatypeConstraintComponent on <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1>>.
# Milliseconds to evaluate shape <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1>: 1.244ms
# Milliseconds to check constraint <PropertyConstraintComponent on <NodeShape http://example.com/ns#SongShape>>: 2.084ms
# DataGraph conforms to constraint <PropertyConstraintComponent on <NodeShape http://example.com/ns#SongShape>>.
# Milliseconds to evaluate shape <NodeShape http://example.com/ns#SongShape>: 2.983ms
# Checking if Shape <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1> defines its own targets.
# Identifying targets to find focus nodes.
# Milliseconds to find focus nodes: 0.026ms
# Found 0 Focus Nodes to evaluate.
# Skipping shape <PropertyShape nd1fe0a1b2e99493c8c5eafdd4d5afa49b1> because it found no focus nodes.
# True
# b'@prefix sh: <http://www.w3.org/ns/shacl#> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n[] a sh:ValidationReport ;\n    sh:conforms true .\n\n'
# Validation Report
# Conforms: True
